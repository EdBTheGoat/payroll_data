# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
pay = pd.read_csv("Citywide_Payroll_Data__Fiscal_Year_ (1).csv")
pay
# Out:
#        Fiscal Year  Payroll Number                  Agency Name  \
# 0             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 1             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 2             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 3             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 4             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 5             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 6             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 7             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 8             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 9             2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 10            2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 11            2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 12            2019            67.0    ADMIN FOR CHILDREN'S SVCS
# 13            2019            67.0    ADMIN FOR CHILDREN'S SVCS
# ...

# %%
pay_counts = pay["Agency Name"].value_counts()
pay_counts
# Out:
# POLICE DEPARTMENT                 1860
# DEPT OF ED PEDAGOGICAL            1816
# DEPT OF PARKS & RECREATION        1791
# DEPT OF ED PARA PROFESSIONALS     1280
# DEPT OF ED PER SESSION TEACHER    1236
# DEPT OF ED HRLY SUPPORT STAFF     1141
# FIRE DEPARTMENT                    932
# ADMIN FOR CHILDREN'S SVCS          765
# DEPARTMENT OF SANITATION           614
# NYC HOUSING AUTHORITY              567
# DEPT OF HEALTH/MENTAL HYGIENE      493
# DEPARTMENT OF CORRECTION           428
# DEPARTMENT OF EDUCATION ADMIN      415
# HRA/DEPT OF SOCIAL SERVICES        402
# DEPT OF ENVIRONMENT PROTECTION     379
# COMMUNITY COLLEGE (MANHATTAN)      307
# DEPARTMENT OF TRANSPORTATION       272
# COMMUNITY COLLEGE (LAGUARDIA)      239
# LAW DEPARTMENT                     199
# DISTRICT ATTORNEY-MANHATTAN        193
# HOUSING PRESERVATION & DVLPMNT     191
# DEPT OF CITYWIDE ADMIN SVCS        188
# COMMUNITY COLLEGE (KINGSBORO)      178
# DEPARTMENT OF FINANCE              172
# ...

# %%
pay.plot(x = "Agency Name", y = "Base Salary")
